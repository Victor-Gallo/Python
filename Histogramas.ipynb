# %% [markdown]
# ## Histogramas a partir de un Timeseries
# Primero se debe importar las librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Luego, cargar el archivo que contiene la información.
# El argumento "Index_col" se utiliza para indicar que columna será el indice, en este caso en la columna de posición cero (0)

# %%
pm = pd.read_csv('D:/VICTOR/Manejo de Cuencas/Manejo de Cuencas/3_Resultados/pm.csv', index_col = 0)
pm
# Out:
#              CHALILLA  SAN DAMIAN  SANTIAGO DE TUNA   ANTIOQUIA  CIENEGUILLA  \
# Fecha
# 1/01/1981   73.540390   65.878136         14.586435   10.004867     0.817586
# 1/02/1981  101.419601  183.381332         33.009388   39.011810     0.082931
# 1/03/1981  176.794815  210.111069         44.597309  122.407761     0.000927
# 1/04/1981    4.356437    9.333351          0.183039    2.038014     0.071737
# 1/05/1981    0.273717    0.070582          0.000000    0.000000     0.259797
# ...               ...         ...               ...         ...          ...
# 1/08/2021    0.739057    0.712986          0.787439    0.223247     3.668288
# 1/09/2021    1.917689    1.614844          1.291618    0.666720     2.934791
# 1/10/2021   12.008654   14.768636          7.448258    6.851452     3.307142
# 1/11/2021   18.315670   20.980951          6.924269    3.730295     3.369602
# 1/12/2021   43.964676   44.393280         18.029989   19.154839     2.781803
#
#                 LANGA  MANCHAY BAJO  SAN LAZARO DE ESCOMARCA  ATOCONGO
# Fecha
# 1/01/1981   65.878136      0.817586                43.546803  0.770403
# 1/02/1981  183.381332      0.082931               212.646484  0.027009
# 1/03/1981  210.111069      0.000927               182.286179  0.046097
# 1/04/1981    9.333351      0.071737                18.452427  0.000000
# 1/05/1981    0.070582      0.259797                 0.000000  0.000000
# ...               ...           ...                      ...       ...
# 1/08/2021    0.712986      3.668288                 0.346936  3.207693
# 1/09/2021    1.614844      2.934791                 2.097353  2.506334
# 1/10/2021   14.768636      3.307142                20.453196  2.090168
# 1/11/2021   20.980951      3.369602                42.546631  2.484860
# 1/12/2021   44.393280      2.781803                43.601074  2.350670
#
# [492 rows x 9 columns]

# %%
Chalilla = pm['CHALILLA'].plot(kind='line', figsize = (10,5))
plt.title('Chalilla')
plt.xlabel('Meses')
plt.ylabel('mm/mes')
# Out:
# Text(0, 0.5, 'mm/mes')

# %% [markdown]
# Histogramas

# %% [markdown]
# Histogramas con subplots

# %%
fig = plt.figure()
ax0 = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)
ax2 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)
plt.subplots_adjust(wspace=0.3, hspace=0.5)


pm['CHALILLA'].plot(kind='line', figsize = (15,6), ax = ax0).set_title('Chalilla')
ax0.set_ylabel('mm/mes')
pm['SAN DAMIAN'].plot(kind='line', figsize = (15,6), ax = ax1).set_title('San Damian')
ax1.set_ylabel('mm/mes')
pm['LANGA'].plot(kind='line', figsize = (15,6), ax = ax2).set_title('Langa')
ax2.set_ylabel('mm/mes')
pm['ANTIOQUIA'].plot(kind='line', figsize = (15,6), ax = ax3).set_title('Antioquía')
ax3.set_ylabel('mm/mes')
# Out:
# Text(0, 0.5, 'mm/mes')

# %%
plt.style.use('seaborn')

fig = plt.figure()
ax0 = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)
ax2 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)
plt.subplots_adjust(wspace=0.3, hspace=0.5)


pm['CHALILLA'].plot(kind='line', figsize = (15,6), ax = ax0).set_title('Chalilla')
ax0.set_ylabel('mm/mes')
pm['SAN DAMIAN'].plot(kind='line', figsize = (15,6), ax = ax1).set_title('San Damian')
ax1.set_ylabel('mm/mes')
pm['LANGA'].plot(kind='line', figsize = (15,6), ax = ax2).set_title('Langa')
ax2.set_ylabel('mm/mes')
pm['ANTIOQUIA'].plot(kind='line', figsize = (15,6), ax = ax3).set_title('Antioquía')
ax3.set_ylabel('mm/mes')
# Out:
# Text(0, 0.5, 'mm/mes')
