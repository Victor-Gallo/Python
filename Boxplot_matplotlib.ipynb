# %% [markdown]
# ## Boxplot a partir de un Timeseries
# Primero se debe importar las librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Luego, cargar el archivo que contiene la información

# %%
pm = pd.read_csv('D:/VICTOR/Manejo de Cuencas/Manejo de Cuencas/3_Resultados/2021/data_pp_2021.csv', parse_dates = True, index_col = 0)
pm
# Out:
#               CHALILLA  SAN.DAMIAN  SANTIAGO.DE.TUNA   ANTIOQUIA  CIENEGUILLA  \
# Fecha
# 1981-01-01   73.540390   65.878136         14.586435   10.004867     0.817586
# 1981-02-01  101.419601  183.381332         33.009388   39.011810     0.082931
# 1981-03-01  176.794815  210.111069         44.597309  122.407761     0.000927
# 1981-04-01    4.356437    9.333351          0.183039    2.038014     0.071737
# 1981-05-01    0.273717    0.070582          0.000000    0.000000     0.259797
# ...                ...         ...               ...         ...          ...
# 2021-08-01    0.739057    0.712986          0.787439    0.223247     3.668288
# 2021-09-01    1.917689    1.614844          1.291618    0.666720     2.934791
# 2021-10-01   12.008654   14.768636          7.448258    6.851452     3.307142
# 2021-11-01   18.315670   20.980951          6.924269    3.730295     3.369602
# 2021-12-01   43.964676   44.393280         18.029989   19.154839     2.781803
#
# ...

# %% [markdown]
# Histogramas

# %%
Chalilla = pm['CHALILLA'].plot(kind='line', figsize = (12,5))
            plt.title('Chalilla')
            plt.xlabel('Meses')
            plt.ylabel('mm/mes')
# Out:
# Text(0, 0.5, 'mm/mes')

# %% [markdown]
# Histogramas con subplots

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=2, ncols=2, figsize=(12,6))

ax1.plot(Chalilla)
ax1.set_xlabel('Meses')
ax1.set_ylabel('mm')
         
ax2.plot(pm['SAN.DAMIAN'].plot(kind='line')
ax2.set_xlabel('Meses')
ax2.set_ylabel('mm')

plt.show()
# Out:
#   File "<ipython-input-20-feae8a5ccba9>", line 8
#     ax2.set_xlabel('Meses')
#     ^
# SyntaxError: invalid syntax
